# %%
import pandas as pd

# %%
data = pd.read_csv("employees.csv")
data.head()
# Out:
#   First Name  Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas    Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas    Male  3/31/1996         6:53 AM   61933    4.170
# 2      Maria  Female  4/23/1993        11:17 AM  130590   11.858
# 3      Jerry    Male   3/4/2005         1:00 PM  138705    9.340
# 4      Larry    Male  1/24/1998         4:47 PM  101004    1.389
#
#   Senior Management             Team
# 0              True        Marketing
# 1              True              NaN
# 2             False          Finance
# 3              True          Finance
# 4              True  Client Services

# %%
data.dtypes
# Out:
# First Name            object
# Gender                object
# Start Date            object
# Last Login Time       object
# Salary                 int64
# Bonus %              float64
# Senior Management     object
# Team                  object
# dtype: object

# %%
data["Start Date"] = pd.to_datetime(data["Start Date"])

# %%
data["Last Login Time"] = pd.to_datetime(data["Last Login Time"])

# %%
data.dtypes
# Out:
# First Name                   object
# Gender                       object
# Start Date           datetime64[ns]
# Last Login Time      datetime64[ns]
# Salary                        int64
# Bonus %                     float64
# Senior Management            object
# Team                         object
# dtype: object

# %%
data["Senior Management"] = data["Senior Management"].astype("category")

# %%
data["Gender"] = data["Gender"].astype("category")

# %%
data.dtypes
# Out:
# First Name                   object
# Gender                     category
# Start Date           datetime64[ns]
# Last Login Time      datetime64[ns]
# Salary                        int64
# Bonus %                     float64
# Senior Management          category
# Team                         object
# dtype: object

# %%
data["Gender"] == "Male"
# Out:
# 0       True
# 1       True
# 2      False
# 3       True
# 4       True
#        ...
# 995    False
# 996     True
# 997     True
# 998     True
# 999     True
# Name: Gender, Length: 1000, dtype: bool

# %%
data[data["Gender"] == "Male"]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2021-11-22 12:42:00   97308    6.945
# 1       Thomas   Male 1996-03-31 2021-11-22 06:53:00   61933    4.170
# 3        Jerry   Male 2005-03-04 2021-11-22 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2021-11-22 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2021-11-22 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 994     George   Male 2013-06-21 2021-11-22 17:47:00   98874    4.479
# 996    Phillip   Male 1984-01-31 2021-11-22 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2021-11-22 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2021-11-22 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2021-11-22 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# 3                True               Finance
# 4                True       Client Services
# 5               False                 Legal
# ..                ...                   ...
# 994              True             Marketing
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [424 rows x 8 columns]

# %%
data.columns
# Out:
# Index(['First Name', 'Gender', 'Start Date', 'Last Login Time', 'Salary',
#        'Bonus %', 'Senior Management', 'Team'],
#       dtype='object')

# %%
mask = data["Bonus %"] > 10

# %%
data[mask]
# Out:
#     First Name  Gender Start Date     Last Login Time  Salary  Bonus %  \
# 2        Maria  Female 1993-04-23 2021-11-22 11:17:00  130590   11.858
# 5       Dennis    Male 1987-04-18 2021-11-22 01:35:00  115163   10.125
# 6         Ruby  Female 1987-08-17 2021-11-22 16:20:00   65476   10.012
# 7          NaN  Female 2015-07-20 2021-11-22 10:43:00   45906   11.598
# 8       Angela  Female 2005-11-22 2021-11-22 06:29:00   95570   18.523
# ..         ...     ...        ...                 ...     ...      ...
# 993       Tina  Female 1997-05-15 2021-11-22 15:53:00   56450   19.040
# 995      Henry     NaN 2014-11-23 2021-11-22 06:09:00  132483   16.655
# 996    Phillip    Male 1984-01-31 2021-11-22 06:30:00   42392   19.675
# 998      Larry    Male 2013-04-20 2021-11-22 16:45:00   60500   11.985
# 999     Albert    Male 2012-05-15 2021-11-22 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 2               False               Finance
# 5               False                 Legal
# 6                True               Product
# 7                 NaN               Finance
# 8                True           Engineering
# ..                ...                   ...
# 993              True           Engineering
# 995             False          Distribution
# 996             False               Finance
# 998             False  Business Development
# 999              True                 Sales
#
# [495 rows x 8 columns]

# %%
mask1 = data["Team"] == "Engineering"

# %%
mask2 = data["Gender"] = "Male"

# %%
data[data["Team"].notnull()]
# Out:
#     First Name Gender Start Date     Last Login Time  Salary  Bonus %  \
# 0      Douglas   Male 1993-08-06 2021-11-22 12:42:00   97308    6.945
# 2        Maria   Male 1993-04-23 2021-11-22 11:17:00  130590   11.858
# 3        Jerry   Male 2005-03-04 2021-11-22 13:00:00  138705    9.340
# 4        Larry   Male 1998-01-24 2021-11-22 16:47:00  101004    1.389
# 5       Dennis   Male 1987-04-18 2021-11-22 01:35:00  115163   10.125
# ..         ...    ...        ...                 ...     ...      ...
# 995      Henry   Male 2014-11-23 2021-11-22 06:09:00  132483   16.655
# 996    Phillip   Male 1984-01-31 2021-11-22 06:30:00   42392   19.675
# 997    Russell   Male 2013-05-20 2021-11-22 12:39:00   96914    1.421
# 998      Larry   Male 2013-04-20 2021-11-22 16:45:00   60500   11.985
# 999     Albert   Male 2012-05-15 2021-11-22 18:24:00  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# 3                True               Finance
# 4                True       Client Services
# 5               False                 Legal
# ..                ...                   ...
# 995             False          Distribution
# 996             False               Finance
# 997             False               Product
# 998             False  Business Development
# 999              True                 Sales
#
# [957 rows x 8 columns]

# %%
data["Gender"].unique()
# Out:
# array(['Male'], dtype=object)

# %%
data["Gender"].nunique()
# Out:
# 1
