# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.sort_values(by=["Country", "WorkWeekHrs"], ascending=[True, False], inplace=True)

# %%
df[["Country", "WorkWeekHrs"]]
# Out:
#                 Country  WorkWeekHrs
# Respondent
# 35295       Afghanistan        100.0
# 2932        Afghanistan         90.0
# 9839        Afghanistan         60.0
# 44484       Afghanistan         60.0
# 57269       Afghanistan         52.0
# ...                 ...          ...
# 60055               NaN          NaN
# 61121               NaN          NaN
# 61570               NaN          NaN
# 61918               NaN          NaN
# 62605               NaN          NaN
#
# [64461 rows x 2 columns]

# %%
#To see largest and smallest values
df["WorkWeekHrs"].nlargest()
# Out:
# Respondent
# 22487    475.0
# 45667    425.0
# 15607    425.0
# 45841    425.0
# 34857    425.0
# Name: WorkWeekHrs, dtype: float64

# %%
df["WorkWeekHrs"].nsmallest()
# Out:
# Respondent
# 17894    1.0
# 27390    1.0
# 6188     1.0
# 21351    1.0
# 40965    1.0
# Name: WorkWeekHrs, dtype: float64

# %%
#In case if we want to apply nlargest to a complete dataframe..to see first 10

df.nlargest(10, "CompTotal")
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 43070                          I am a developer by profession      Yes   NaN
# 48098       I am not primarily a developer, but I write co...       No   NaN
# 46711                          I am a developer by profession      Yes   NaN
# 2638                           I am a developer by profession       No  99.0
# 50343       I am not primarily a developer, but I write co...      Yes   NaN
# 21351                          I am a developer by profession       No  98.0
# 6993        I am not primarily a developer, but I write co...      Yes   NaN
# 48289                          I am a developer by profession      Yes   NaN
# 2499        I am not primarily a developer, but I write co...       No   NaN
# 40965       I am not primarily a developer, but I write co...       No   NaN
#
#                       Age1stCode CompFreq      CompTotal  ConvertedComp  \
# Respondent
# ...

# %%
df.nsmallest(10, "CompTotal")
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 27135       I am a developer by profession       No   NaN         16   Yearly
# 5548        I am a developer by profession       No  44.0         17      NaN
# 6054        I am a developer by profession      Yes  38.0         15   Yearly
# 60292       I am a developer by profession      Yes   NaN         12   Yearly
# 38813       I am a developer by profession       No   NaN         18  Monthly
# 14069       I am a developer by profession      Yes  29.0         15      NaN
# 41006       I am a developer by profession      Yes  22.0         17   Yearly
# 15493       I am a developer by profession       No  44.0         17  Monthly
# 57369       I am a developer by profession       No  44.0         18  Monthly
# 28845       I am a developer by profession       No  26.0         16  Monthly
#
#             CompTotal  ConvertedComp     Country       CurrencyDesc  \
# Respondent
# ...
