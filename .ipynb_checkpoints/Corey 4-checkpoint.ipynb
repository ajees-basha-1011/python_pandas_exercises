# %%
import pandas as pd

# %%
df = pd.read_csv('survey_results_public.csv', index_col='Respondent')
schema_df = pd.read_csv('survey_results_schema.csv', index_col='Column')

# %%
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
#To filter work hours greater than 30
long_work_hours = df["WorkWeekHrs"] > 30

# %%
#using loc we are filtering the columns JobFactors,LanguageDesireNextYear
df.loc[long_work_hours, ["JobFactors","LanguageDesireNextYear"]].head()
# Out:
#                                                    JobFactors  \
# Respondent
# 1           Languages, frameworks, and other technologies ...
# 4           Flex time or a flexible schedule;Office enviro...
# 8           Remote work options;Opportunities for professi...
# 9           Diversity of the company or organization;Remot...
# 10          Flex time or a flexible schedule;How widely us...
#
#                            LanguageDesireNextYear
# Respondent
# 1                          C#;HTML/CSS;JavaScript
# 4                                             NaN
# 8                                      JavaScript
# 9                                     Python;Rust
# 10          HTML/CSS;Java;JavaScript;Python;R;SQL

# %%
#To grab specific countries
countries = ["India", "Germany", "Cananda"]
filt = df["Country"].isin(countries)

# %%
df[filt].head()
# Out:
#                                 MainBranch Hobbyist   Age Age1stCode CompFreq  \
# Respondent
# 1           I am a developer by profession      Yes   NaN         13  Monthly
# 6           I am a developer by profession       No   NaN         14      NaN
# 7           I am a developer by profession      Yes   NaN         18  Monthly
# 22          I am a developer by profession      Yes   NaN         18  Monthly
# 23          I am a developer by profession      Yes  27.0         14      NaN
#
#             CompTotal  ConvertedComp  Country          CurrencyDesc  \
# Respondent
# 1                 NaN            NaN  Germany         European Euro
# 6                 NaN            NaN  Germany         European Euro
# 7                 NaN            NaN    India  United States dollar
# 22                NaN            NaN    India          Indian rupee
# 23                NaN            NaN  Germany         European Euro
#
#            CurrencySymbol DatabaseDesireNextYear  \
# ...

# %%
filt = df["WebframeWorkedWith"].str.contains("Ruby", na=False)

# %%
df.loc[filt, "WebframeWorkedWith"]
# Out:
# Respondent
# 5                                            Ruby on Rails
# 48                                    Gatsby;Ruby on Rails
# 59                    ASP.NET;jQuery;Laravel;Ruby on Rails
# 67                                           Ruby on Rails
# 91                                    jQuery;Ruby on Rails
#                                ...
# 55074    Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 56163    Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 56263                         Angular;jQuery;Ruby on Rails
# 59168    Angular;Angular.js;ASP.NET;ASP.NET Core;Django...
# 62391            Angular.js;Express;React.js;Ruby on Rails
# Name: WebframeWorkedWith, Length: 2944, dtype: object
