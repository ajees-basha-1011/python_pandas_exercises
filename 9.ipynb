# %%
import pandas as pd

# %%
data = pd.read_csv("jamesbond.csv")
data.head()
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967   David Niven     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
mask = data["Actor"] = "Sean Connery"

# %%
data.loc[mask, "Actor"] = "Sir"

# %%
data.head()
# Out:
#                     Film    Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962.0  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963.0  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964.0  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965.0  Sean Connery  Terence Young       848.1
# 4          Casino Royale  1967.0  Sean Connery     Ken Hughes       315.0
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7
# 4    85.0                NaN

# %%
data.drop(["Film", "Year"], axis="columns")
# Out:
#                      Actor            Director  Box Office  Budget  \
# 0             Sean Connery       Terence Young       448.8     7.0
# 1             Sean Connery       Terence Young       543.8    12.6
# 2             Sean Connery        Guy Hamilton       820.4    18.6
# 3             Sean Connery       Terence Young       848.1    41.9
# 4             Sean Connery          Ken Hughes       315.0    85.0
# 5             Sean Connery       Lewis Gilbert       514.2    59.9
# 6             Sean Connery       Peter R. Hunt       291.5    37.3
# 7             Sean Connery        Guy Hamilton       442.5    34.7
# 8             Sean Connery        Guy Hamilton       460.3    30.8
# 9             Sean Connery        Guy Hamilton       334.0    27.7
# 10            Sean Connery       Lewis Gilbert       533.0    45.1
# 11            Sean Connery       Lewis Gilbert       535.0    91.5
# 12            Sean Connery           John Glen       449.4    60.2
# ...

# %%
data.sample(n=5)
# Out:
#                      Film    Year         Actor        Director  Box Office  \
# 17        Licence to Kill  1989.0  Sean Connery       John Glen       250.9
# 13  Never Say Never Again  1983.0  Sean Connery  Irvin Kershner       380.0
# 5     You Only Live Twice  1967.0  Sean Connery   Lewis Gilbert       514.2
# 2              Goldfinger  1964.0  Sean Connery    Guy Hamilton       820.4
# 3             Thunderball  1965.0  Sean Connery   Terence Young       848.1
#
#     Budget  Bond Actor Salary
# 17    56.7                7.9
# 13    86.0                NaN
# 5     59.9                4.4
# 2     18.6                3.2
# 3     41.9                4.7

# %%
data["Box Office"].nlargest(3)
# Out:
# 24    943.5
# 3     848.1
# 2     820.4
# Name: Box Office, dtype: float64

# %%
data["Box Office"].nsmallest(3)
# Out:
# 17    250.9
# 15    275.2
# 6     291.5
# Name: Box Office, dtype: float64

# %%
mask = data["Actor"] == "Sean Connery"
data.where(mask)
# Out:
#                                          Film    Year         Actor  \
# 0                                      Dr. No  1962.0  Sean Connery
# 1                       From Russia with Love  1963.0  Sean Connery
# 2                                  Goldfinger  1964.0  Sean Connery
# 3                                 Thunderball  1965.0  Sean Connery
# 4                               Casino Royale  1967.0  Sean Connery
# 5                         You Only Live Twice  1967.0  Sean Connery
# 6             On Her Majesty's Secret Service  1969.0  Sean Connery
# 7                        Diamonds Are Forever  1971.0  Sean Connery
# 8                            Live and Let Die  1973.0  Sean Connery
# 9                 The Man with the Golden Gun  1974.0  Sean Connery
# 10                       The Spy Who Loved Me  1977.0  Sean Connery
# 11                                  Moonraker  1979.0  Sean Connery
# 12                         For Your Eyes Only  1981.0  Sean Connery
# ...
